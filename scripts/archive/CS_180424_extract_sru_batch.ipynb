# %%
import requests
from lxml import etree as et

ns = {
    'srw': 'http://www.loc.gov/zing/srw/',
    'marc': 'http://www.loc.gov/MARC21/slim'
}
sru_url = 'https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB'
p = {
    'version': '1.2',
    'operation': 'searchRetrieve',
    'maximumRecords': 50
}
max_records = 50

# %%
params = p.copy()
query = 'alma.national_bibliography_number=OeBC and alma.local_field_970=56 and alma.main_pub_date>2009'
params['query'] = query
params['startRecord'] = 1
marc_results = []

while params['startRecord']:
    res = requests.get(sru_url, params=params)
    root = et.fromstring(res.content)
    marc_results += root.xpath('//srw:records/srw:record', namespaces=ns)
    start_record = root.find('.//srw:nextRecordPosition', namespaces=ns)
    num_results = int(root.find('.//srw:numberOfRecords', namespaces=ns).text)
    if start_record != None:
        start_record = int(start_record.text)
    print(params['startRecord'], num_results, res.url)
    params['startRecord'] = start_record

results = et.Element('results')
[results.append(r) for r in marc_results]

et.ElementTree(results).write('CS_220424_extract_sru_after2009_xmlresults.xml')
# Out:
# 1 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=1
# 51 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=51
# 101 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=101
# 151 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=151
# 201 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=201
# 251 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=251
# 301 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=301
# 351 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=351
# 401 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=401
# 451 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=451
# 501 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=501
# 551 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=551
# 601 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=601
# 651 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=651
# 701 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=701
# 751 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=751
# 801 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=801
# 851 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=851
# 901 9906 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3E2009&startRecord=901
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/vk/bmtds1lj3sb5yqxll664dvwr0000gn/T/ipykernel_18875/4206090765.py in <module>
#       6
#       7 while params['startRecord']:
# ----> 8     res = requests.get(sru_url, params=params)
#       9     root = et.fromstring(res.content)
#      10     marc_results += root.xpath('//srw:records/srw:record', namespaces=ns)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
params = p.copy()
query = 'alma.national_bibliography_number=OeBC and alma.local_field_970=56 and alma.main_pub_date<2009'
params['query'] = query
params['startRecord'] = 1
marc_results = []

while params['startRecord']:
    res = requests.get(sru_url, params=params)
    root = et.fromstring(res.content)
    marc_results += root.xpath('//srw:records/srw:record', namespaces=ns)
    start_record = root.find('.//srw:nextRecordPosition', namespaces=ns)
    num_results = int(root.find('.//srw:numberOfRecords', namespaces=ns).text)
    if start_record != None:
        start_record = int(start_record.text)
    print(params['startRecord'], num_results, res.url)
    params['startRecord'] = start_record

results = et.Element('results')
[results.append(r) for r in marc_results]

et.ElementTree(results).write('CS_220424_extract_sru_before2009_xmlresults.xml')
# Out:
# 1 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1
# 51 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=51
# 101 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=101
# 151 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=151
# 201 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=201
# 251 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=251
# 301 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=301
# 351 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=351
# 401 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=401
# 451 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=451
# 501 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=501
# 551 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=551
# 601 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=601
# 651 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=651
# 701 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=701
# 751 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=751
# 801 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=801
# 851 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=851
# 901 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=901
# 951 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=951
# 1001 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1001
# 1051 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1051
# 1101 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1101
# 1151 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1151
# 1201 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1201
# 1251 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1251
# 1301 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1301
# 1351 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1351
# 1401 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1401
# 1451 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1451
# 1501 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1501
# 1551 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1551
# 1601 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1601
# 1651 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1651
# 1701 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1701
# 1751 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1751
# 1801 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1801
# 1851 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1851
# 1901 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1901
# 1951 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=1951
# 2001 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2001
# 2051 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2051
# 2101 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2101
# 2151 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2151
# 2201 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2201
# 2251 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2251
# 2301 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2301
# 2351 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2351
# 2401 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2401
# 2451 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2451
# 2501 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2501
# 2551 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2551
# 2601 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2601
# 2651 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2651
# 2701 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2701
# 2751 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2751
# 2801 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2801
# 2851 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2851
# 2901 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2901
# 2951 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=2951
# 3001 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3001
# 3051 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3051
# 3101 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3101
# 3151 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3151
# 3201 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3201
# 3251 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3251
# 3301 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3301
# 3351 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3351
# 3401 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3401
# 3451 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3451
# 3501 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3501
# 3551 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3551
# 3601 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3601
# 3651 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3651
# 3701 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3701
# 3751 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3751
# 3801 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3801
# 3851 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3851
# 3901 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3901
# 3951 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=3951
# 4001 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4001
# 4051 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4051
# 4101 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4101
# 4151 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4151
# 4201 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4201
# 4251 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4251
# 4301 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4301
# 4351 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4351
# 4401 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4401
# 4451 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4451
# 4501 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4501
# 4551 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4551
# 4601 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4601
# 4651 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4651
# 4701 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4701
# 4751 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4751
# 4801 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4801
# 4851 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4851
# 4901 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4901
# 4951 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=4951
# 5001 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5001
# 5051 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5051
# 5101 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5101
# 5151 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5151
# 5201 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5201
# 5251 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5251
# 5301 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5301
# 5351 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5351
# 5401 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5401
# 5451 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5451
# 5501 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5501
# 5551 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5551
# 5601 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5601
# 5651 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5651
# 5701 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5701
# 5751 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5751
# 5801 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5801
# 5851 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5851
# 5901 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5901
# 5951 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=5951
# 6001 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6001
# 6051 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6051
# 6101 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6101
# 6151 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6151
# 6201 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6201
# 6251 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6251
# 6301 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6301
# 6351 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6351
# 6401 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6401
# 6451 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6451
# 6501 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6501
# 6551 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6551
# 6601 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6601
# 6651 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6651
# 6701 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6701
# 6751 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6751
# 6801 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6801
# 6851 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6851
# 6901 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6901
# 6951 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=6951
# 7001 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=7001
# 7051 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=7051
# 7101 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=7101
# 7151 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=7151
# 7201 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=7201
# 7251 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=7251
# 7301 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=7301
# 7351 7396 https://obv-at-oenb.alma.exlibrisgroup.com/view/sru/43ACC_ONB?version=1.2&operation=searchRetrieve&maximumRecords=50&query=alma.national_bibliography_number%3DOeBC+and+alma.local_field_970%3D56+and+alma.main_pub_date%3C2009&startRecord=7351

# %%
# filter results
results.findall('.//marc:record/marc:datafield[@tag="041"]/marc:subfield[@code="h"]', namespaces=ns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/vk/bmtds1lj3sb5yqxll664dvwr0000gn/T/ipykernel_18875/1087685949.py in <module>
#       1 # filter results
# ----> 2 results.findall('.//marc:record/marc:datafield[@tag="041"]/marc:subfield[@code="h"]', namespaces=ns)
#
# NameError: name 'results' is not defined
